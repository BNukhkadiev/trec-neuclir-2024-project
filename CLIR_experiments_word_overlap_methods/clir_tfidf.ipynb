# %%
# !pip install ir_datasets
# !pip install ir_measures
# !pip install deep_translator
# !pip install razdel
# !pip install stopwordsiso
# !pip3 install "ir-measures[cwl_eval]"
# Out:
# Requirement already satisfied: ir_datasets in /usr/local/lib/python3.10/dist-packages (0.5.9)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.12.3)
# Requirement already satisfied: inscriptis>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (2.5.0)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (5.3.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (1.26.4)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (6.0.2)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.66.6)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.3.3)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.1.9)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (3.3.0)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->ir_datasets) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir_datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir_datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir_datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir_datasets) (2024.8.30)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from trec-car-tools>=2.5.4->ir_datasets) (1.0.0)
# Requirement already satisfied: ir_measures in /usr/local/lib/python3.10/dist-packages (0.3.6)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.5 in /usr/local/lib/python3.10/dist-packages (from ir_measures) (0.5.6)
# Collecting deep_translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2024.8.30)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: deep_translator
# Successfully installed deep_translator-1.11.4
# Requirement already satisfied: razdel in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: stopwordsiso in /usr/local/lib/python3.10/dist-packages (0.6.1)
# Requirement already satisfied: ir-measures[cwl_eval] in /usr/local/lib/python3.10/dist-packages (0.3.6)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.5 in /usr/local/lib/python3.10/dist-packages (from ir-measures[cwl_eval]) (0.5.6)
# Requirement already satisfied: cwl-eval>=1.0.10 in /usr/local/lib/python3.10/dist-packages (from ir-measures[cwl_eval]) (1.0.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from cwl-eval>=1.0.10->ir-measures[cwl_eval]) (1.26.4)

# %%
import ir_datasets
from collections import defaultdict
from tqdm.notebook import tqdm
from collections import Counter
from deep_translator import GoogleTranslator
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import string
import ir_measures
from ir_measures import nDCG, MAP, RBP, Recall, Qrel, ScoredDoc
from itertools import chain
from razdel import tokenize
from nltk.stem.snowball import SnowballStemmer
import string
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load data

# %%
# loading dataset and qrels for further evaluation
dataset = ir_datasets.load("neuclir/1/ru/trec-2023")
qrels = [(qrel.query_id, qrel.doc_id, qrel.relevance) for qrel in dataset.qrels_iter()]

# %%
# extracting documents, queries and qrels
russian_documents = [(doc.doc_id, doc.title, doc.text) for doc in tqdm(dataset.docs_iter())]
english_queries = [(query.query_id, query.title) for query in dataset.queries_iter()]
qrels = [(qrel.query_id, qrel.doc_id, qrel.relevance) for qrel in dataset.qrels_iter()]
# Out:
# 0it [00:00, ?it/s]
# [INFO] If you have a local copy of https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true, you can symlink it here to avoid downloading it again: /root/.ir_datasets/downloads/3aabc798a3b5dd92d7c47db9521870b1
# [INFO] [starting] https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true
#
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 0.0%| 0.00/4.50G [00:00<?, ?B/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 0.3%| 11.5M/4.50G [00:00<00:39, 114MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 0.6%| 26.7M/4.50G [00:00<00:33, 133MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 1.0%| 43.7M/4.50G [00:00<00:30, 145MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 1.3%| 60.6M/4.50G [00:00<00:29, 148MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 1.7%| 77.6M/4.50G [00:00<00:29, 151MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 2.1%| 95.3M/4.50G [00:00<00:28, 155MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 2.5%| 114M/4.50G [00:00<00:27, 159MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 2.9%| 132M/4.50G [00:00<00:27, 160MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 3.3%| 150M/4.50G [00:00<00:27, 160MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 3.7%| 169M/4.50G [00:01<00:26, 162MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 4.1%| 187M/4.50G [00:01<00:26, 162MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 4.6%| 205M/4.50G [00:01<00:26, 164MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 5.0%| 224M/4.50G [00:01<00:25, 165MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 5.4%| 242M/4.50G [00:01<00:25, 167MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 5.8%| 261M/4.50G [00:01<00:26, 161MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 6.2%| 279M/4.50G [00:01<00:26, 162MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 6.6%| 298M/4.50G [00:01<00:25, 162MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 7.0%| 316M/4.50G [00:01<00:25, 162MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 7.4%| 335M/4.50G [00:02<00:25, 162MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 7.8%| 353M/4.50G [00:02<00:25, 163MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 8.3%| 372M/4.50G [00:02<00:25, 164MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 8.7%| 390M/4.50G [00:02<00:25, 164MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 9.1%| 409M/4.50G [00:02<00:24, 165MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 9.5%| 428M/4.50G [00:02<00:24, 166MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 9.9%| 446M/4.50G [00:02<00:24, 166MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 10.3%| 465M/4.50G [00:02<00:24, 166MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 10.7%| 483M/4.50G [00:02<00:24, 166MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 11.1%| 502M/4.50G [00:03<00:24, 167MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 11.6%| 520M/4.50G [00:03<00:23, 166MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 12.0%| 539M/4.50G [00:03<00:23, 166MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 12.4%| 557M/4.50G [00:03<00:23, 166MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 12.8%| 576M/4.50G [00:03<00:23, 165MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 13.2%| 594M/4.50G [00:03<00:23, 166MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 13.6%| 613M/4.50G [00:03<00:23, 166MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 14.0%| 632M/4.50G [00:03<00:23, 166MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 14.4%| 650M/4.50G [00:03<00:23, 166MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 14.8%| 669M/4.50G [00:04<00:23, 167MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 15.3%| 687M/4.50G [00:04<00:22, 167MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 15.7%| 706M/4.50G [00:04<00:22, 167MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 16.1%| 724M/4.50G [00:04<00:22, 168MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 16.5%| 743M/4.50G [00:04<00:22, 168MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 16.9%| 761M/4.50G [00:04<00:22, 168MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 17.3%| 780M/4.50G [00:04<00:22, 168MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 17.7%| 798M/4.50G [00:04<00:22, 168MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 18.1%| 817M/4.50G [00:04<00:21, 168MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 18.6%| 836M/4.50G [00:04<00:21, 168MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 19.0%| 854M/4.50G [00:05<00:21, 169MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 19.4%| 873M/4.50G [00:05<00:21, 169MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 19.8%| 891M/4.50G [00:05<00:21, 169MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 20.2%| 910M/4.50G [00:05<00:21, 169MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 20.6%| 928M/4.50G [00:05<00:21, 169MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 21.0%| 947M/4.50G [00:05<00:21, 168MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 21.4%| 965M/4.50G [00:05<00:21, 168MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 21.8%| 984M/4.50G [00:05<00:20, 168MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 22.3%| 1.00G/4.50G [00:05<00:20, 168MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 22.7%| 1.02G/4.50G [00:06<00:20, 168MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 23.1%| 1.04G/4.50G [00:06<00:20, 169MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 23.5%| 1.06G/4.50G [00:06<00:20, 169MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 23.9%| 1.08G/4.50G [00:06<00:20, 169MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 24.3%| 1.10G/4.50G [00:06<00:20, 169MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 24.7%| 1.11G/4.50G [00:06<00:20, 169MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 25.1%| 1.13G/4.50G [00:06<00:19, 169MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 25.6%| 1.15G/4.50G [00:06<00:19, 169MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 26.0%| 1.17G/4.50G [00:06<00:19, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 26.4%| 1.19G/4.50G [00:06<00:19, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 26.8%| 1.21G/4.50G [00:07<00:19, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 27.2%| 1.23G/4.50G [00:07<00:19, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 27.6%| 1.24G/4.50G [00:07<00:19, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 28.0%| 1.26G/4.50G [00:07<00:19, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 28.4%| 1.28G/4.50G [00:07<00:18, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 28.8%| 1.30G/4.50G [00:07<00:18, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 29.3%| 1.32G/4.50G [00:07<00:18, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 29.7%| 1.34G/4.50G [00:07<00:18, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 30.1%| 1.35G/4.50G [00:07<00:18, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 30.5%| 1.37G/4.50G [00:08<00:18, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 30.9%| 1.39G/4.50G [00:08<00:18, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 31.3%| 1.41G/4.50G [00:08<00:18, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 31.7%| 1.43G/4.50G [00:08<00:18, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 32.1%| 1.45G/4.50G [00:08<00:17, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 32.6%| 1.47G/4.50G [00:08<00:17, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 33.0%| 1.48G/4.50G [00:08<00:17, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 33.4%| 1.50G/4.50G [00:08<00:17, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 33.8%| 1.52G/4.50G [00:08<00:17, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 34.2%| 1.54G/4.50G [00:09<00:17, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 34.6%| 1.56G/4.50G [00:09<00:17, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 35.0%| 1.58G/4.50G [00:09<00:17, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 35.4%| 1.60G/4.50G [00:09<00:17, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 35.8%| 1.61G/4.50G [00:09<00:16, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 36.3%| 1.63G/4.50G [00:09<00:16, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 36.7%| 1.65G/4.50G [00:09<00:16, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 37.1%| 1.67G/4.50G [00:09<00:16, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 37.5%| 1.69G/4.50G [00:09<00:16, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 37.9%| 1.71G/4.50G [00:09<00:16, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 38.3%| 1.73G/4.50G [00:10<00:16, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 38.7%| 1.74G/4.50G [00:10<00:16, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 39.1%| 1.76G/4.50G [00:10<00:16, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 39.6%| 1.78G/4.50G [00:10<00:15, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 40.0%| 1.80G/4.50G [00:10<00:15, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 40.4%| 1.82G/4.50G [00:10<00:15, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 40.8%| 1.84G/4.50G [00:10<00:15, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 41.2%| 1.86G/4.50G [00:10<00:15, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 41.6%| 1.87G/4.50G [00:10<00:15, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 42.0%| 1.89G/4.50G [00:11<00:15, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 42.4%| 1.91G/4.50G [00:11<00:15, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 42.8%| 1.93G/4.50G [00:11<00:14, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 43.3%| 1.95G/4.50G [00:11<00:14, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 43.7%| 1.97G/4.50G [00:11<00:14, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 44.1%| 1.99G/4.50G [00:11<00:14, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 44.5%| 2.00G/4.50G [00:11<00:14, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 44.9%| 2.02G/4.50G [00:11<00:14, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 45.3%| 2.04G/4.50G [00:11<00:14, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 45.7%| 2.06G/4.50G [00:11<00:14, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 46.1%| 2.08G/4.50G [00:12<00:14, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 46.6%| 2.10G/4.50G [00:12<00:13, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 47.0%| 2.12G/4.50G [00:12<00:13, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 47.4%| 2.13G/4.50G [00:12<00:13, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 47.8%| 2.15G/4.50G [00:12<00:13, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 48.2%| 2.17G/4.50G [00:12<00:13, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 48.6%| 2.19G/4.50G [00:12<00:13, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 49.0%| 2.21G/4.50G [00:12<00:13, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 49.4%| 2.23G/4.50G [00:12<00:13, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 49.8%| 2.25G/4.50G [00:13<00:13, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 50.3%| 2.26G/4.50G [00:13<00:13, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 50.7%| 2.28G/4.50G [00:13<00:12, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 51.1%| 2.30G/4.50G [00:13<00:12, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 51.5%| 2.32G/4.50G [00:13<00:12, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 51.9%| 2.34G/4.50G [00:13<00:12, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 52.3%| 2.36G/4.50G [00:13<00:12, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 52.7%| 2.37G/4.50G [00:13<00:12, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 53.1%| 2.39G/4.50G [00:13<00:12, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 53.6%| 2.41G/4.50G [00:14<00:12, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 54.0%| 2.43G/4.50G [00:14<00:12, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 54.4%| 2.45G/4.50G [00:14<00:11, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 54.8%| 2.47G/4.50G [00:14<00:11, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 55.2%| 2.49G/4.50G [00:14<00:11, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 55.6%| 2.50G/4.50G [00:14<00:11, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 56.0%| 2.52G/4.50G [00:14<00:11, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 56.4%| 2.54G/4.50G [00:14<00:11, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 56.8%| 2.56G/4.50G [00:14<00:11, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 57.3%| 2.58G/4.50G [00:15<00:11, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 57.7%| 2.60G/4.50G [00:15<00:11, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 58.1%| 2.62G/4.50G [00:15<00:10, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 58.5%| 2.63G/4.50G [00:15<00:10, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 58.9%| 2.65G/4.50G [00:15<00:10, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 59.3%| 2.67G/4.50G [00:15<00:10, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 59.7%| 2.69G/4.50G [00:15<00:10, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 60.1%| 2.71G/4.50G [00:15<00:10, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 60.6%| 2.73G/4.50G [00:15<00:10, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 61.0%| 2.75G/4.50G [00:15<00:10, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 61.4%| 2.76G/4.50G [00:16<00:10, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 61.8%| 2.78G/4.50G [00:16<00:09, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 62.2%| 2.80G/4.50G [00:16<00:09, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 62.6%| 2.82G/4.50G [00:16<00:09, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 63.0%| 2.84G/4.50G [00:16<00:09, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 63.4%| 2.86G/4.50G [00:16<00:09, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 63.8%| 2.88G/4.50G [00:16<00:09, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 64.3%| 2.89G/4.50G [00:16<00:09, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 64.7%| 2.91G/4.50G [00:16<00:09, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 65.1%| 2.93G/4.50G [00:17<00:09, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 65.5%| 2.95G/4.50G [00:17<00:09, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 65.9%| 2.97G/4.50G [00:17<00:08, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 66.3%| 2.99G/4.50G [00:17<00:08, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 66.7%| 3.01G/4.50G [00:17<00:08, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 67.1%| 3.02G/4.50G [00:17<00:08, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 67.6%| 3.04G/4.50G [00:17<00:08, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 68.0%| 3.06G/4.50G [00:17<00:08, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 68.4%| 3.08G/4.50G [00:17<00:08, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 68.8%| 3.10G/4.50G [00:18<00:08, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 69.2%| 3.12G/4.50G [00:18<00:08, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 69.6%| 3.14G/4.50G [00:18<00:07, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 70.0%| 3.15G/4.50G [00:18<00:07, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 70.4%| 3.17G/4.50G [00:18<00:07, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 70.8%| 3.19G/4.50G [00:18<00:07, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 71.3%| 3.21G/4.50G [00:18<00:07, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 71.7%| 3.23G/4.50G [00:18<00:07, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 72.1%| 3.25G/4.50G [00:18<00:07, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 72.5%| 3.27G/4.50G [00:18<00:07, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 72.9%| 3.28G/4.50G [00:19<00:07, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 73.3%| 3.30G/4.50G [00:19<00:06, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 73.7%| 3.32G/4.50G [00:19<00:06, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 74.1%| 3.34G/4.50G [00:19<00:06, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 74.6%| 3.36G/4.50G [00:19<00:06, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 75.0%| 3.38G/4.50G [00:19<00:06, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 75.4%| 3.40G/4.50G [00:19<00:06, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 75.8%| 3.41G/4.50G [00:19<00:06, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 76.2%| 3.43G/4.50G [00:19<00:06, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 76.6%| 3.45G/4.50G [00:20<00:06, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 77.0%| 3.47G/4.50G [00:20<00:06, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 77.4%| 3.49G/4.50G [00:20<00:05, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 77.8%| 3.51G/4.50G [00:20<00:05, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 78.3%| 3.52G/4.50G [00:20<00:05, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 78.7%| 3.54G/4.50G [00:20<00:05, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 79.1%| 3.56G/4.50G [00:20<00:05, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 79.5%| 3.58G/4.50G [00:20<00:05, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 79.9%| 3.60G/4.50G [00:20<00:05, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 80.3%| 3.62G/4.50G [00:21<00:05, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 80.7%| 3.64G/4.50G [00:21<00:05, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 81.1%| 3.65G/4.50G [00:21<00:04, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 81.6%| 3.67G/4.50G [00:21<00:04, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 82.0%| 3.69G/4.50G [00:21<00:04, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 82.4%| 3.71G/4.50G [00:21<00:04, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 82.8%| 3.73G/4.50G [00:21<00:04, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 83.2%| 3.75G/4.50G [00:21<00:04, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 83.6%| 3.77G/4.50G [00:21<00:04, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 84.0%| 3.78G/4.50G [00:22<00:04, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 84.4%| 3.80G/4.50G [00:22<00:04, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 84.8%| 3.82G/4.50G [00:22<00:03, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 85.3%| 3.84G/4.50G [00:22<00:03, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 85.7%| 3.86G/4.50G [00:22<00:03, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 86.1%| 3.88G/4.50G [00:22<00:03, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 86.5%| 3.90G/4.50G [00:22<00:03, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 86.9%| 3.91G/4.50G [00:22<00:03, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 87.3%| 3.93G/4.50G [00:22<00:03, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 87.7%| 3.95G/4.50G [00:23<00:03, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 88.1%| 3.97G/4.50G [00:23<00:03, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 88.6%| 3.99G/4.50G [00:23<00:03, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 89.0%| 4.01G/4.50G [00:23<00:02, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 89.4%| 4.03G/4.50G [00:23<00:02, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 89.8%| 4.04G/4.50G [00:23<00:02, 172MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 90.2%| 4.06G/4.50G [00:23<00:02, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 90.6%| 4.08G/4.50G [00:23<00:02, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 91.0%| 4.10G/4.50G [00:24<00:02, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 91.4%| 4.12G/4.50G [00:24<00:02, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 91.8%| 4.14G/4.50G [00:24<00:02, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 92.3%| 4.16G/4.50G [00:24<00:02, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 92.7%| 4.17G/4.50G [00:24<00:01, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 93.1%| 4.19G/4.50G [00:24<00:01, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 93.5%| 4.21G/4.50G [00:24<00:01, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 93.9%| 4.23G/4.50G [00:24<00:01, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 94.3%| 4.25G/4.50G [00:24<00:01, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 94.7%| 4.27G/4.50G [00:25<00:01, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 95.1%| 4.29G/4.50G [00:25<00:01, 170MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 95.6%| 4.30G/4.50G [00:25<00:01, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 96.0%| 4.32G/4.50G [00:25<00:01, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 96.4%| 4.34G/4.50G [00:25<00:00, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 96.8%| 4.36G/4.50G [00:25<00:00, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 97.2%| 4.38G/4.50G [00:25<00:00, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 97.6%| 4.40G/4.50G [00:25<00:00, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 98.0%| 4.42G/4.50G [00:25<00:00, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 98.4%| 4.43G/4.50G [00:25<00:00, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 98.8%| 4.45G/4.50G [00:26<00:00, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 99.3%| 4.47G/4.50G [00:26<00:00, 171MB/s]
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: 99.7%| 4.49G/4.50G [00:26<00:00, 171MB/s]
# [INFO] [finished] https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: [00:26] [4.50GB] [171MB/s]
#
# https://huggingface.co/datasets/neuclir/neuclir1/resolve/main/data/rus-00000-of-00001.jsonl.gz?download=true: [00:26] [4.50GB] [171MB/s]
#                                                                                                                                         [INFO] [starting] https://trec.nist.gov/data/neuclir/2023/neuclir-2023-topics.0605.jsonl
# [INFO] [finished] https://trec.nist.gov/data/neuclir/2023/neuclir-2023-topics.0605.jsonl: [00:00] [107B] [695kB/s]
# [WARNING] Download failed: Expected md5 hash to be 3dbb41b02bfbd719d8b55632d9b15b83 but got ff4ed829ffd04e9c6095842b07d11f09
# [INFO] [starting] https://mirror.ir-datasets.com/3dbb41b02bfbd719d8b55632d9b15b83
# [INFO] [finished] https://mirror.ir-datasets.com/3dbb41b02bfbd719d8b55632d9b15b83: [00:00] [684kB] [19.1MB/s]

# %%
# filtering out the documents that are present in qrels (for which relevance feedback is available)
qrels_ids = {entry[1] for entry in tqdm(qrels)}
russian_documents_subset = [doc for doc in tqdm(russian_documents) if doc[0] in qrels_ids]
len(russian_documents_subset)
# Out:
#   0%|          | 0/25634 [00:00<?, ?it/s]
#   0%|          | 0/4627543 [00:00<?, ?it/s]
# 24871

# %% [markdown]
# ### Helper functions

# %%
def evaluate(qrels, result):

    runs = [
        ScoredDoc(query_id=query_id, doc_id=doc_id, score=score)
        for query_id, doc_id, score in result
    ]

    metrics = [
        ir_measures.nDCG @ 20,   # nDCG@20
        ir_measures.AP,          # Average Precision
        #ir_measures.RBP(rel=1),  # Relevance Based Precision
        ir_measures.R @ 100,     # Recall@100
        ir_measures.R @ 1000     # Recall@1000
    ]

#     scores = ir_measures.calc_aggregate([nDCG@20, MAP, RBP(rel=1), Recall@100, Recall@1000], qrels, runs)
    scores = ir_measures.calc_aggregate([nDCG@20, MAP, Recall@100, Recall@1000], qrels, runs)

    return scores

def print_document(document_id, collection):
    print(next((doc for doc in collection if doc[0] == document_id), None))

    from collections import defaultdict

def rbp(retrieved_results, qrels, p=0.8):
    # Create a dictionary of relevant documents for each query from qrels
    qrels_dict = defaultdict(set)

    # Unpack qrels and store relevant documents per query_id
    for qrel in qrels:
        query_id = qrel.query_id
        doc_id = qrel.doc_id
        relevance = qrel.relevance
        if relevance > 0:
            qrels_dict[query_id].add(doc_id)

    # Group the retrieved results by query_id
    grouped_retrieved_results = defaultdict(list)
    for query_id, doc_id, score in retrieved_results:
        grouped_retrieved_results[query_id].append((doc_id, score))

    # Initialize the rbp_scores dictionary
    rbp_scores = {}

    # Iterate over the grouped retrieved results
    for query_id, retrieved_docs in grouped_retrieved_results.items():
        score = 0
        # Rank each document for the query
        for rank, (doc_id, _) in enumerate(retrieved_docs, start=1):
            if doc_id in qrels_dict.get(query_id, set()):
                score += (1 - p) * (p ** (rank - 1))
        rbp_scores[query_id] = score

    return rbp_scores

def translate_query(query):
    translated_text = GoogleTranslator(source='auto', target='ru').translate(query[1])
    translated_tuple = (query[0], translated_text)

    return translated_tuple


def combine_documents(documents):
    combine_documents =  list(map(lambda doc: (doc[0], doc[1] + ' ' + doc[2]), documents))
    return combine_documents


import stopwordsiso




def preprocess(text, remove_stop: bool=True) -> list:
    """
    :text: str, text of the corresponding document
    :param remove_stop: bool indicating if stopwords should be removed (default True)

    :return: list(str) of tokens, stemmed, with removed punctuation
    """

    tokens = [_.text for _ in list(tokenize(text))]

    preprocessed =[]

    stemmer = SnowballStemmer("russian")
    stopwords_ru = stopwordsiso.stopwords("ru")
    punct = string.punctuation + "«»" + "—" + '–'

    for t in tokens:
        if t in punct:
            continue
        if remove_stop and t.lower() in stopwords_ru:
            continue
        preprocessed.append(stemmer.stem(t))

    return preprocessed

# %%
# To search on both document title and text, we will concatenate them, obtaining pairs (document_id, full text (title+text))
combined_documents = combine_documents(russian_documents_subset)
print(combined_documents[-1])
# Out:
# ('20bc2d7b-91d1-428b-aa54-ef112e8a1e69', 'Экс-замминобороны США: ядерную войну запустит искусственный интеллект Вашингтон, , 06:51 — REGNUM О существенной опасности искусственного интеллекта в случае использования его военными заявил бывший заместитель министра обороны США Роберт Уорк, передает Breaking Defense.\n\nИскусственный интеллект Цитата из к/ф «Космическая одиссея 2001 года». Реж. Стэнли Кубрик. 1968. США — Великобритания\n\nПо мнению бывшего сотрудника Пентагона, если допустить искусственный интеллект (ИИ) к принятию решений, то существует вероятность, что имеющиеся риски будут оценены им неверно, и ядерное оружие будет применено в ситуации, когда реальной угрозы не будет существовать.\n\n«Представьте, что в системе управления ядерным оружием есть прогностическая система ИИ, которая запускается по определенным параметрам, — сказал он. — Это гораздо, гораздо, гораздо более тревожная перспектива, чем все опасности, что вы можете представить в связи с применением индивидуального оружия».\n\nПохожим образом, считает Уорк, спроектирована российская система «Периметр». По предположениям бывшего замминистра обороны, система способна запустить межконтинентальные ракеты в сторону США, просто приняв за ядерный взрыв сейсмическую активность.\n\nДля того, чтобы развитие не пошло по катастрофическому сценарию, искусственный интеллект должен применяться в оборонных целях очень умеренно, подытожил Уорк.')

# %%
translated_queries = []
for query in english_queries:
  translated_queries.append(translate_query(query))

# %% [markdown]
# **TF-IDF**

# %% [markdown]
# For the implementation of TF-IDF approach we will employ TfidfVectorizer from scikit-learn. Since it offers incorporation of tokenization and stopword removal, we can pass our translated queries and documents directly.

# %% [markdown]
# We want to first create TF-IDF matrix based on our collection and then be able to pass queries and for each query get a list of documents with their respective cosine similarities ranked in descending order. For that, we will create a class of TF-IDF model with a ranking method.
#
# The initial version of TF-IDF model includes default parameters of scikit-learn implementation:
# - use_idf = True for enabling idf reweighting
# - sublinear_tf meaning that tf scores are presented as the raw term frequencies

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt_tab')
nltk.download('stopwords')


class TfIdfModel:
    def __init__(self, collection):
        # extracting  document IDs and texts
        self.doc_ids, doc_texts = zip(*collection)

        russian_stopwords = list(stopwords.words('russian'))

        # initializing vectorizer that can be applied to tokenized documents
        self.vectorizer = TfidfVectorizer(
            tokenizer=word_tokenize,  # Use NLTK's word_tokenize
            stop_words=russian_stopwords,  # Filter out Russian stopwords
            token_pattern=None  # Disable the internal token pattern to ensure external tokenizer is used
        )

        # fitting the vectorizer on the collection texts and transform
        self.tfidf_matrix = self.vectorizer.fit_transform(doc_texts)

    def rank_documents(self, query, rank_length):
        # extracting query ID and text
        query_id, query_text = query

        # transforming the query text into the vector space
        query_vector = self.vectorizer.transform([query_text])

        # Compute cosine similarities between query vector and precomputed matrix
        cosine_similarities = cosine_similarity(query_vector, self.tfidf_matrix).flatten()

        # Pair each document ID with its corresponding cosine similarity score
        scored_documents = [(doc_id, similarity) for doc_id, similarity in zip(self.doc_ids, cosine_similarities)]

        # Sort documents by similarity score in descending order
        sorted_documents = sorted(scored_documents, key=lambda x: x[1], reverse=True)

        # Return ranked data
        ranked_data = [(query_id, uuid, value) for uuid, value in sorted_documents[:rank_length]]
        return ranked_data
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# we will fit the model on out document collection
model = TfIdfModel(combined_documents)

# %%
ranked_tfidf = []

for query in tqdm(translated_queries):
  rank_per_query = model.rank_documents(query, 1000)
  ranked_tfidf.append(rank_per_query)

flat_list_tfidf = list(chain.from_iterable(ranked_tfidf))
# Out:
#   0%|          | 0/76 [00:00<?, ?it/s]

# %%
print(flat_list_tfidf[:5])
# Out:
# [('200', '6726a11f-c2fa-4900-98ce-3357ca6a1aee', 0.18275552291010866), ('200', 'd84ebc49-2b1f-433b-b8c5-3f2572d6d273', 0.17262768542184287), ('200', '07135ef0-9faf-40fd-8cd0-f93ddca8a071', 0.16772486188206254), ('200', 'd21fe9e4-c71d-46b5-9ee3-8e8541c2a5ee', 0.1483759392238966), ('200', '2dc72e68-74be-43f3-9585-ccd42173258a', 0.140650921328917)]

# %%
qrels = [
    ir_measures.Qrel(query_id=query_id, doc_id=doc_id, relevance=score)
    for query_id, doc_id, score in qrels
]

# %%
performance_tfidf = evaluate(qrels, flat_list_tfidf)

# %%
RBP_tfidf = rbp(flat_list_tfidf, qrels)
RBP_1_tfidf = sum(RBP_tfidf.values()) / len(RBP_tfidf)
performance_tfidf["RBP(rel=1)"] = RBP_1_tfidf

# %%
print("Evaluation Metrics (TF-IDF):")
for metric, value in performance_tfidf.items():
    print(f"{metric}: {value}")
# Out:
# Evaluation Metrics (TF-IDF):
# R@100: 0.3672248482825866
# R@1000: 0.709934318552958
# AP: 0.17401886311677012
# nDCG@20: 0.25476337535496335
# RBP(rel=1): 0.28032323527912495

# %% [markdown]
# We want to see if we can improve the results with our customized language-specific preprocessing function. In order to bypass the inbuilt tokenization and pass as input lists of tokens as documents, we create an additional "dummy" function (solution suggested by David Batista https://www.davidsbatista.net/blog/2018/02/28/TfidfVectorizer/)

# %%
def dummy_function(x):
    return x

# %%
#we preprocess all documents (tokenization, dropping punctuation and stopwords, stemming)
preprocessed_documents = [
    (doc_id, preprocess(doc_text))
    for doc_id, doc_text in combined_documents
]

# %%
#we preprocess every query (tokenization, dropping punctuation and stopwords, stemming)
preprocessed_queries = [
    (query_id, preprocess(query_text))
    for query_id, query_text in translated_queries
]

# %%
#we redifine TfidfModel class

class TfIdfModel:
    def __init__(self, collection):
        # extracting  document IDs and texts
        self.doc_ids, doc_texts = zip(*collection)

        # initializing vectorizer that can be applied to tokenized documents
        self.vectorizer = TfidfVectorizer(
            analyzer='word',
            tokenizer=dummy_function,
            preprocessor=dummy_function,
            token_pattern=None
        )

        # fitting the vectorizer on the collection texts and transform
        self.tfidf_matrix = self.vectorizer.fit_transform(doc_texts)

    def rank_documents(self, query, rank_length):
        # extracting query ID and text
        query_id, query_text = query

        # transforming the query text into the vector space
        query_vector = self.vectorizer.transform([query_text])

        # Compute cosine similarities between query vector and precomputed matrix
        cosine_similarities = cosine_similarity(query_vector, self.tfidf_matrix).flatten()

        # Pair each document ID with its corresponding cosine similarity score
        scored_documents = [(doc_id, similarity) for doc_id, similarity in zip(self.doc_ids, cosine_similarities)]

        # Sort documents by similarity score in descending order
        sorted_documents = sorted(scored_documents, key=lambda x: x[1], reverse=True)

        # Return ranked data
        ranked_data = [(query_id, uuid, value) for uuid, value in sorted_documents[:rank_length]]
        return ranked_data

# %%
# we will fit the model on out document collection
model = TfIdfModel(preprocessed_documents)

# %%
ranked_tfidf = []

for query in tqdm(preprocessed_queries):
  rank_per_query = model.rank_documents(query, 1000)
  ranked_tfidf.append(rank_per_query)

flat_list_tfidf = list(chain.from_iterable(ranked_tfidf))
# Out:
#   0%|          | 0/76 [00:00<?, ?it/s]

# %%
print(flat_list_tfidf[:5])
# Out:
# [('200', 'dbc0d493-44a5-4f5f-84ce-066d341a44a6', 0.5098904767089345), ('200', '21a96c19-6e65-4ad7-a5f1-bc51db6cd15c', 0.37061867956941574), ('200', '07135ef0-9faf-40fd-8cd0-f93ddca8a071', 0.3103747068071534), ('200', '0c1e52d0-4f1d-4109-9fb3-b84a4b0c99d9', 0.30283719434355616), ('200', 'c8cf62b1-d540-4524-995b-f01445ed351d', 0.29710340340092156)]

# %%
performance_tfidf = evaluate(qrels, flat_list_tfidf)

# %%
RBP_tfidf = rbp(flat_list_tfidf, qrels)
RBP_1_tfidf = sum(RBP_tfidf.values()) / len(RBP_tfidf)
performance_tfidf["RBP(rel=1)"] = RBP_1_tfidf

# %%
print("Evaluation Metrics (TF-IDF):")
for metric, value in performance_tfidf.items():
    print(f"{metric}: {value}")
# Out:
# Evaluation Metrics (TF-IDF):
# R@100: 0.44144864004908346
# AP: 0.2575902476455747
# nDCG@20: 0.30057360879973816
# R@1000: 0.8839690860680056
# RBP(rel=1): 0.32165782651910335

# %% [markdown]
# We want to improve the obtained results by modifying some parameters of the parameters. To begin, instead of taking raw term frequencies, we will use logarithm tf weighing: 1 + log(tf), by modifying sublinear_tf parameter of the vectorizer

# %%
class TfIdfModel_v2:
    def __init__(self, collection):
        # extracting  document IDs and texts
        self.doc_ids, doc_texts = zip(*collection)

        # initializing vectorizer that can be applied to tokenized documents
        self.vectorizer = TfidfVectorizer(
            analyzer='word',
            tokenizer=dummy_function,
            preprocessor=dummy_function,
            token_pattern=None,
            sublinear_tf=True
        )

        # fitting the vectorizer on the collection texts and transform
        self.tfidf_matrix = self.vectorizer.fit_transform(doc_texts)

    def rank_documents(self, query, rank_length):
        # extracting query ID and text
        query_id, query_text = query

        # transforming the query text into the vector space
        query_vector = self.vectorizer.transform([query_text])

        # Compute cosine similarities between query vector and precomputed matrix
        cosine_similarities = cosine_similarity(query_vector, self.tfidf_matrix).flatten()

        # Pair each document ID with its corresponding cosine similarity score
        scored_documents = [(doc_id, similarity) for doc_id, similarity in zip(self.doc_ids, cosine_similarities)]

        # Sort documents by similarity score in descending order
        sorted_documents = sorted(scored_documents, key=lambda x: x[1], reverse=True)

        # Return ranked data
        ranked_data = [(query_id, uuid, value) for uuid, value in sorted_documents[:rank_length]]
        return ranked_data

# %%
model_v2 = TfIdfModel_v2(preprocessed_documents)

# %%
ranked_tfidf_v2 = []

for query in tqdm(preprocessed_queries):
  rank_per_query = model_v2.rank_documents(query, 1000)
  ranked_tfidf_v2.append(rank_per_query)

flat_list_tfidf_v2 = list(chain.from_iterable(ranked_tfidf_v2))
# Out:
#   0%|          | 0/76 [00:00<?, ?it/s]

# %%
performance_tfidf_v2 = evaluate(qrels, flat_list_tfidf_v2)

# %%
RBP_tfidf_v2 = rbp(flat_list_tfidf_v2, qrels)
RBP_1_tfidf_v2 = sum(RBP_tfidf_v2.values()) / len(RBP_tfidf_v2)
performance_tfidf_v2["RBP(rel=1)"] = RBP_1_tfidf_v2

# %%
print("Evaluation Metrics (TF-IDF):")
for metric, value in performance_tfidf_v2.items():
    print(f"{metric}: {value}")
# Out:
# Evaluation Metrics (TF-IDF):
# R@100: 0.48378915616448215
# AP: 0.28001360925051477
# nDCG@20: 0.3196050100708838
# R@1000: 0.8855943757303283
# RBP(rel=1): 0.3646633901989546

# %% [markdown]
# With different tf weighing we achieved a slight improvement in ranking performance, since we accounted for non-linear nature of raltion between term frequency and document relevance.
#
# We will try to improve it further by normalizing the term frequencies by the frequency of the most frequent term in the document. This option is not available within scikit-learn TfidfVectorizer, but we can implement it as a postprocessing step of the tfidf matrix

# %%
from scipy.sparse import csr_matrix

class TfIdfModel_v3:
    def __init__(self, collection):
        # extracting document IDs and texts
        self.doc_ids, doc_texts = zip(*collection)

        # initialize TfidfVectorizer with sublinear_tf=True
        self.vectorizer = TfidfVectorizer(
            analyzer='word',
            tokenizer=dummy_function,
            preprocessor=dummy_function,
            token_pattern=None,
            sublinear_tf=True
        )

        # fitting and transforming the documents to get the TF-IDF matrix
        X = self.vectorizer.fit_transform(doc_texts)

        max_per_row = np.array(X.max(axis=1).toarray()).flatten()

        # compute the normalization factors: 1 + log(max_value_in_row)
        normalization_factors = 1 + np.log(max_per_row)

        # to avoid division by zero (in case there are empty rows):
        normalization_factors[normalization_factors == -np.inf] = 1  # we replace -inf with 1 for empty rows

        # scaling the sparse matrix rows
        X = X.multiply(1 / normalization_factors[:, np.newaxis])




        # max_per_row = np.array(tfidf_matrix.max(axis=1)).flatten()

        # normalization_factors = 1 + np.log(max_per_row)

        # tfidf_matrix = tfidf_matrix.multiply(1 / normalization_factors[:, np.newaxis])

        #print(type(tfidf_matrix))

        #tfidf_matrix = tfidf_matrix/(1 + np.log(max(tfidf_matrix, axis=1, keepdims=True)))

        self.tfidf_matrix = X



    def rank_documents(self, query, rank_length):
        # extracting query ID and text
        query_id, query_text = query

        # transforming the query text into the vector space
        query_vector = self.vectorizer.transform([query_text])

        # Compute cosine similarities between query vector and precomputed matrix
        cosine_similarities = cosine_similarity(query_vector, self.tfidf_matrix).flatten()

        # Pair each document ID with its corresponding cosine similarity score
        scored_documents = [(doc_id, similarity) for doc_id, similarity in zip(self.doc_ids, cosine_similarities)]

        # Sort documents by similarity score in descending order
        sorted_documents = sorted(scored_documents, key=lambda x: x[1], reverse=True)

        # Return ranked data
        ranked_data = [(query_id, uuid, value) for uuid, value in sorted_documents[:rank_length]]
        return ranked_data

# %%
model_v3 = TfIdfModel_v3(preprocessed_documents)

# %%
ranked_tfidf_v3 = []

for query in tqdm(preprocessed_queries):
  rank_per_query = model_v3.rank_documents(query, 1000)
  ranked_tfidf_v3.append(rank_per_query)

flat_list_tfidf_v3 = list(chain.from_iterable(ranked_tfidf_v3))
# Out:
#   0%|          | 0/76 [00:00<?, ?it/s]

# %%
performance_tfidf_v3 = evaluate(qrels, flat_list_tfidf_v3)

# %%
RBP_tfidf_v3 = rbp(flat_list_tfidf_v3, qrels)
RBP_1_tfidf_v3 = sum(RBP_tfidf_v3.values()) / len(RBP_tfidf_v3)
performance_tfidf_v3["RBP(rel=1)"] = RBP_1_tfidf_v3

# %%
print("Evaluation Metrics (TF-IDF):")
for metric, value in performance_tfidf_v3.items():
    print(f"{metric}: {value}")
# Out:
# Evaluation Metrics (TF-IDF):
# R@100: 0.040253658252453195
# AP: 0.017423518704029393
# nDCG@20: 0.09514186832897815
# R@1000: 0.042338365724836874
# RBP(rel=1): 0.14500773263987515

# %%
class TfIdfModel_v4:
    def __init__(self, collection):
        # extracting  document IDs and texts
        self.doc_ids, doc_texts = zip(*collection)

        # initializing vectorizer that can be applied to tokenized documents
        self.vectorizer = TfidfVectorizer(
            analyzer='word',
            tokenizer=dummy_function,
            preprocessor=dummy_function,
            token_pattern=None,
            #max_df=0.1,
            min_df=0.001,
            sublinear_tf=True
        )

        # fitting the vectorizer on the collection texts and transform
        self.tfidf_matrix = self.vectorizer.fit_transform(doc_texts)

    def rank_documents(self, query, rank_length):
        # extracting query ID and text
        query_id, query_text = query

        # transforming the query text into the vector space
        query_vector = self.vectorizer.transform([query_text])

        # Compute cosine similarities between query vector and precomputed matrix
        cosine_similarities = cosine_similarity(query_vector, self.tfidf_matrix).flatten()

        # Pair each document ID with its corresponding cosine similarity score
        scored_documents = [(doc_id, similarity) for doc_id, similarity in zip(self.doc_ids, cosine_similarities)]

        # Sort documents by similarity score in descending order
        sorted_documents = sorted(scored_documents, key=lambda x: x[1], reverse=True)

        # Return ranked data
        ranked_data = [(query_id, uuid, value) for uuid, value in sorted_documents[:rank_length]]
        return ranked_data

# %%
model_v4 = TfIdfModel_v4(preprocessed_documents)

# %%
ranked_tfidf_v4 = []

for query in tqdm(preprocessed_queries):
  rank_per_query = model_v4.rank_documents(query, 1000)
  ranked_tfidf_v4.append(rank_per_query)

flat_list_tfidf_v4 = list(chain.from_iterable(ranked_tfidf_v4))
# Out:
#   0%|          | 0/76 [00:00<?, ?it/s]

# %%
performance_tfidf_v4 = evaluate(qrels, flat_list_tfidf_v4)

# %%
RBP_tfidf_v4 = rbp(flat_list_tfidf_v4, qrels)
RBP_1_tfidf_v4 = sum(RBP_tfidf_v4.values()) / len(RBP_tfidf_v4)
performance_tfidf_v4["RBP(rel=1)"] = RBP_1_tfidf_v4

# %%
print("Evaluation Metrics (TF-IDF):")
for metric, value in performance_tfidf_v4.items():
    print(f"{metric}: {value}")
# Out:
# Evaluation Metrics (TF-IDF):
# R@100: 0.4663502418118479
# AP: 0.26342769052296783
# nDCG@20: 0.291976199867674
# R@1000: 0.8758607845640082
# RBP(rel=1): 0.32950576091683986

# %%
# since we already have our custom preprocessing, we will use a function
def dummy_function(x):
    return x

def tf_idf(query, documents):
    # extracting the query and documents texts
    query_id, query_text = query
    doc_ids, doc_texts = zip(*documents)  # unzip the document tuples into ids and texts

    # Combine the query text with the document texts for vectorization
    texts = [query_text] + list(doc_texts)

    # Create the TF-IDF Vectorizer

    vectorizer = TfidfVectorizer(
    analyzer='word',
    tokenizer=dummy_function,
    preprocessor=dummy_function,
    token_pattern=None)

    # Fit and transform the text data
    tfidf_matrix = vectorizer.fit_transform(texts)

    # Extract the query vector (the first row in the matrix)
    query_vector = tfidf_matrix[0:1]

    # Compute the cosine similarity between the query vector and the document vectors
    cosine_similarities = cosine_similarity(query_vector, tfidf_matrix[1:]).flatten()

    # Pair each document id with its corresponding cosine similarity score
    scored_documents = [(doc_id, similarity) for doc_id, similarity in zip(doc_ids, cosine_similarities)]

    # Sort documents by similarity score in descending order
    sorted_documents = sorted(scored_documents, key=lambda x: x[1], reverse=True)

    ranked_data = [(query_id, uuid, value) for uuid, value in sorted_documents[:1000]]

    return ranked_data

# %%
ranked_tfidf = []
for query in tqdm(preprocessed_queries):
    scores_tfidf = tf_idf(query, preprocessed_documents)
    ranked_tfidf.append(scores_tfidf)

flat_list_tfidf = list(chain.from_iterable(ranked_tfidf))
# Out:
#   0%|          | 0/76 [00:00<?, ?it/s]

# %%
print(flat_list_tfidf[:5])
# Out:
# [('200', 'dbc0d493-44a5-4f5f-84ce-066d341a44a6', 0.5094508855965356), ('200', '21a96c19-6e65-4ad7-a5f1-bc51db6cd15c', 0.3703436596888059), ('200', '07135ef0-9faf-40fd-8cd0-f93ddca8a071', 0.3100856813869644), ('200', '0c1e52d0-4f1d-4109-9fb3-b84a4b0c99d9', 0.3027228759686717), ('200', 'c8cf62b1-d540-4524-995b-f01445ed351d', 0.29675834193817796)]

# %% [markdown]
# **Evaluation of TF-IDF ranking**

# %%
qrels = [
    ir_measures.Qrel(query_id=row['query_id'], doc_id=row['doc_id'], relevance=row['relevance'])
    for _, row in qrels_pd.iterrows()
]

# %%
performance_tfidf = evaluate(qrels, flat_list_tfidf)

# %%
RBP_tfidf = rbp(flat_list_tfidf, qrels)
RBP_1_tfidf = sum(RBP_tfidf.values()) / len(RBP_tfidf)
performance_tfidf["RBP(rel=1)"] = RBP_1_tfidf
# Out:
# RBP(rel=1): 0.32054686075827377

# %%
print("Evaluation Metrics (TF-IDF):")
for metric, value in performance_tfidf.items():
    print(f"{metric}: {value}")
